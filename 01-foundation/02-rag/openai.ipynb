# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
response = openai_client.responses.create(
    model="gpt-4o-mini",
    input="Write an betime story about a unicorn"
)

# %%
print(response.output_text)
# Out:
# **The Starry Night Unicorn**
#
# Once upon a time, in a shimmering land called Luminara, there lived a gentle unicorn named Lumi. She had a sparkling silver coat that glimmered under the moonlight and a majestic horn that shimmered like the stars. Every night, Lumi would wander through the enchanted forest, where the trees whispered secrets and the flowers bloomed with magic.
#
# One evening, as the sun dipped below the horizon, Lumi noticed something unusual. The night sky was darker than ever, and the stars seemed to be hiding away. Concerned, she trotted toward the Rainbow River, where her friend Bella, a wise old owl, lived.
#
# "Hello, Lumi!" hooted Bella, flapping her large, feathered wings. "What brings you here on such a dark night?"
#
# “Bella,” Lumi said, worry etched on her face, “the stars are missing! We need them to light up the night and guide the dreamers.”
#
# ...
